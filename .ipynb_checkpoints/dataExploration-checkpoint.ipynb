# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
### Read in training dataset (TSV)
# Filepath will be different; set to repo's filepath when we add the corpus files
train_tsv = pd.read_csv('scicite/tsv/train.tsv', sep='\t', 
                       names=["citingPaperID", "source", "string", "label"]
                       )
train_tsv
# Out:
#                                           citingPaperID    source  \
# 0     1872080baa7d30ec8fb87be9a65358cd3a7fb649>894be...  explicit
# 1     ce1d09a4a3a8d7fd3405b9328f65f00c952cf64b>b6642...  explicit
# 2     9cdf605beb1aa1078f235c4332b3024daa8b31dc>4e6a1...  explicit
# 3     d9f3207db0c79a3b154f3875c9760cc6b056904b>2cc6f...  explicit
# 4     88b86556857f4374842d2af2e359576806239175>a5bb0...  explicit
# ...                                                 ...       ...
# 8238  6f68ccd37718366c40ae6aeedf0b935bf560b215>60ed4...  explicit
# 8239  f2a1c1704f9587c94ed95bc98179dc499e933f5e>574e6...  explicit
# 8240  18c97ea2ff60c110cc2a523e0fdf729608cbb083>fc13b...  explicit
# 8241  4ec9b89857c0b27e8a4bd3745b7358f387773527>81aff...  explicit
# 8242  42c954cad0de68657d4429b512d8fe75dceef13c>00afb...  explicit
#
#                                                  string       label
# 0     However, how frataxin interacts with the Fe-S ...  background
# 1     In the study by Hickey et al. (2012), spikes w...  background
# 2     The drug also reduces catecholamine secretion,...  background
# 3     By clustering with lowly aggressive close kin ...  background
# 4     Ophthalmic symptoms are rare manifestations of...  background
# ...                                                 ...         ...
# 8238  Importantly, the results of Pascalis et al. (2...  background
# 8239  As suggested by Nguena et al, there is a need ...  background
# 8240  Skeletal muscle is also a primary site of dise...  background
# 8241  ACTIVATION OF TRANSCRIPTION FACTORS Roles for ...      method
# 8242  Most studies focused on the relation between b...  background
#
# [8243 rows x 4 columns]

# %%
### Unique "source" values
print(train_tsv["source"].unique(), train_tsv["source"].value_counts())
# Out:
# ['explicit' 'properNoun' 'acronym' 'acronymParen' 'andPhrase' 'etAlPhrase'
#  nan] explicit        7886
# properNoun       142
# acronym          131
# acronymParen      53
# andPhrase         19
# etAlPhrase        10
# Name: source, dtype: int64

# %%
### Unique "label" values
print(train_tsv["label"].unique(), train_tsv["label"].value_counts())
# Out:
# ['background' 'method' 'result'] background    4840
# method        2294
# result        1109
# Name: label, dtype: int64

# %%
### Create a matrix of counts with source-label pair combinations
source_label_dict = {}; source_label_list = []
for index, row in train_tsv.iterrows():
    source_label_pair = str(row['source']) + '_' + row['label']
    # Initialize source-label pair in the dictionary and list if it doesn't exist
    if source_label_pair not in list(source_label_dict.keys()):
        source_label_dict[source_label_pair] = 1
        source_label_list.append(source_label_pair)
    # Else, add 1 to dictionary value
    else:
        source_label_dict[source_label_pair] += 1

# %%
### Get sorted source-label pair dictionary
sorted_source_label_dict = {}
for source_label_pair in sorted(source_label_list):
    sorted_source_label_dict[source_label_pair] = source_label_dict[source_label_pair]
sorted_source_label_dict
# Out:
# {'acronymParen_background': 2,
#  'acronymParen_method': 46,
#  'acronymParen_result': 5,
#  'acronym_background': 2,
#  'acronym_method': 96,
#  'acronym_result': 33,
#  'andPhrase_method': 14,
#  'andPhrase_result': 5,
#  'etAlPhrase_method': 7,
#  'etAlPhrase_result': 3,
#  'explicit_background': 4835,
#  'explicit_method': 2021,
#  'explicit_result': 1030,
#  'nan_result': 2,
#  'properNoun_background': 1,
#  'properNoun_method': 110,
#  'properNoun_result': 31}

# %%
### Histogram for all source-label pair counts in the training dataset
plt.figure(figsize=(10, 8))
plt.title("Source-label pair counts")
plt.xlabel("Source-label pairs"); plt.ylabel("Count")
plt.xticks(rotation=45)
plt.bar(sorted_source_label_dict.keys(), sorted_source_label_dict.values(), color='g')
# Out:
# <BarContainer object of 17 artists>

# %%
noExplicit_pairs = [pair for pair in sorted(source_label_list) if "explicit_" not in pair]
noExplicit_pairs
# Out:
# ['acronymParen_background',
#  'acronymParen_method',
#  'acronymParen_result',
#  'acronym_background',
#  'acronym_method',
#  'acronym_result',
#  'andPhrase_method',
#  'andPhrase_result',
#  'etAlPhrase_method',
#  'etAlPhrase_result',
#  'nan_result',
#  'properNoun_background',
#  'properNoun_method',
#  'properNoun_result']

# %%
### Get sorted source-label pair dictionary without Explicit source
noExplicit_source_label_dict = {}
for source_label_pair in noExplicit_pairs:
    noExplicit_source_label_dict[source_label_pair] = source_label_dict[source_label_pair]
noExplicit_source_label_dict
# Out:
# {'acronymParen_background': 2,
#  'acronymParen_method': 46,
#  'acronymParen_result': 5,
#  'acronym_background': 2,
#  'acronym_method': 96,
#  'acronym_result': 33,
#  'andPhrase_method': 14,
#  'andPhrase_result': 5,
#  'etAlPhrase_method': 7,
#  'etAlPhrase_result': 3,
#  'nan_result': 2,
#  'properNoun_background': 1,
#  'properNoun_method': 110,
#  'properNoun_result': 31}

# %%
### Histogram for all source-label pair counts in the training dataset excluding Explicit source
plt.figure(figsize=(10, 8))
plt.title("Source-label pair counts")
plt.xlabel("Source-label pairs"); plt.ylabel("Count")
plt.xticks(rotation=45)
plt.bar(noExplicit_source_label_dict.keys(), noExplicit_source_label_dict.values(), color='g')
# Out:
# <BarContainer object of 14 artists>

# %% [markdown]
# # Data exploration for jsonl data

# %%
### train_jsonl
# Parsing the jsonl files
import jsonlines

train_jsonl_list = []

with jsonlines.open('scicite/jsonl/train.jsonl') as f:
    for line in f.iter():
        train_jsonl_list.append(line)

# Putting the jsonl files into a pandas dataframe
train_jsonl = pd.DataFrame(train_jsonl_list)
train_jsonl.head()
# Out:
#      source  citeEnd                                        sectionName  \
# 0  explicit    175.0                                       Introduction
# 1  explicit     36.0  Novel Quantitative Trait Loci for Seminal Root...
# 2  explicit    228.0                                       Introduction
# 3  explicit    110.0                                         Discussion
# 4  explicit    239.0                                         Discussion
#
#    citeStart                                             string       label  \
# 0      168.0  However, how frataxin interacts with the Fe-S ...  background
# 1       16.0  In the study by Hickey et al. (2012), spikes w...  background
# 2      225.0  The drug also reduces catecholamine secretion,...  background
# 3       46.0  By clustering with lowly aggressive close kin ...  background
# 4      234.0  Ophthalmic symptoms are rare manifestations of...  background
#
#    label_confidence                             citingPaperId  \
# 0               1.0  1872080baa7d30ec8fb87be9a65358cd3a7fb649
# 1               1.0  ce1d09a4a3a8d7fd3405b9328f65f00c952cf64b
# 2               1.0  9cdf605beb1aa1078f235c4332b3024daa8b31dc
# 3               1.0  d9f3207db0c79a3b154f3875c9760cc6b056904b
# 4               1.0  88b86556857f4374842d2af2e359576806239175
#
#                                citedPaperId  isKeyCitation  \
# 0  894be9b4ea46a5c422e81ef3c241072d4c73fdc0           True
# 1  b6642e19efb8db5623b3cc4eef1c5822a6151107           True
# 2  4e6a17fb8d7a3cada601d942e22eb5da6d01adbd          False
# 3  2cc6ff899bf17666ad35893524a4d61624555ed7          False
# 4  a5bb0ff1a026944d2a47a155462959af2b8505a8          False
#
#                                                   id  \
# 0  1872080baa7d30ec8fb87be9a65358cd3a7fb649>894be...
# 1  ce1d09a4a3a8d7fd3405b9328f65f00c952cf64b>b6642...
# 2  9cdf605beb1aa1078f235c4332b3024daa8b31dc>4e6a1...
# 3  d9f3207db0c79a3b154f3875c9760cc6b056904b>2cc6f...
# 4  88b86556857f4374842d2af2e359576806239175>a5bb0...
#
#                                            unique_id  excerpt_index label2  \
# 0  1872080baa7d30ec8fb87be9a65358cd3a7fb649>894be...             11    NaN
# 1  ce1d09a4a3a8d7fd3405b9328f65f00c952cf64b>b6642...              2    NaN
# 2  9cdf605beb1aa1078f235c4332b3024daa8b31dc>4e6a1...              0    NaN
# 3  d9f3207db0c79a3b154f3875c9760cc6b056904b>2cc6f...              3    NaN
# 4  88b86556857f4374842d2af2e359576806239175>a5bb0...              2    NaN
#
#    label2_confidence
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
# Plotting train_jsonl's sectionNames
sectionName_dict = {}
for i in np.arange(len(train_jsonl)):
    sectionName = str(train_jsonl['sectionName'][i])
    if sectionName not in sectionName_dict.keys():
        sectionName_dict[sectionName] = 1
    else:
        sectionName_dict[sectionName] += 1
        
# Barplot for all sectionNames in the training dataset
plt.figure(figsize=(10, 8))
plt.title("Training dataset sectionNames")
plt.xlabel("sectionName"); plt.ylabel("Count")
plt.xticks(rotation=15)
plt.bar(sectionName_dict.keys(), sectionName_dict.values(), color='g')
# Out:
# <BarContainer object of 1148 artists>
# /Users/shdpark/miniforge3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9426 (\N{CIRCLED LATIN SMALL LETTER C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
print(len(sectionName_dict), sectionName_dict)
# Informative or not?
# Out:
# 1148 {'Introduction': 834, 'Novel Quantitative Trait Loci for Seminal Root Traits in Barley': 2, 'Discussion': 1240, '3. Discussion': 31, '1. Introduction': 349, 'Implications for Explaining Cooperation: Towards a Classification in Terms of Psychological Mechanisms': 4, 'RESULTS': 162, '3. METHODOLOGY': 1, 'Providing self-determination opportunities': 3, '6. Mitochondrial Lesions': 5, '': 587, 'DISCUSSION': 483, 'GO (cellular component)': 1, '2.1 Economic and Policy Environment': 1, 'Results': 359, 'INTRODUCTION': 263, '6. DISCUSSION': 1, 'MATERIALS AND METHODS': 16, 'Materials and Methods': 30, 'Scope and extensions': 3, 'Background': 101, '1. INTRODUCTION': 54, 'VGluT3': 2, '5.5 Experiments': 1, 'Technical considerations': 6, 'Methods': 800, '1 Introduction': 160, 'Pulse wave velocity': 1, 'Interpretation Bias in Social Anxiety': 4, '2. Methods': 60, 'Method': 87, '4.3 Accuracy': 1, 'Results and discussion': 74, '5.1. Experimental setup': 1, 'Actinobacteria': 1, 'METHODS': 296, 'Implementation': 15, '3. Results': 17, '5. Experimental results': 2, 'Cryostat': 1, 'C. Uplink Capacity Analysis for Massive MIMO': 1, '7 RELATED WORK': 2, '7 Experiments': 4, '2.2. ata Collection': 1, 'Present Address:': 13, '4 EXPERIMENTS': 4, 'Study Design': 1, 'NO, O2': 2, '3 Methodology': 6, '4. Discussion': 172, 'RESULTS AND DISCUSSION': 33, '3.2. Experiment setup': 1, '4.2. Multiple Kernel Learning': 1, '4.1 Experimental Settings': 2, '2.1. Implementation details': 1, '4.2 Node Description': 1, 'Experiments': 10, 'Q Protein of Phage λ': 3, '3.2.4 Concluding remarks on the Seasonal Error Duration Model': 2, '2.2. Implications of a Shallow BDT': 2, 'Experimental Design': 7, '5. Experiments': 7, '4. DISCUSSION': 16, '3. Methodology': 7, 'Results and Discussion': 41, 'GeneSeer search features': 1, 'Virus and cells': 1, '3 Empirical KCEF and consistency': 3, 'As is well known, this concept can be expressed equivalently using a relation ~- between sets of propositions and individual propositions instead of an operation, for example with the following': 1, 'Pharmacokinetic analysis': 1, 'Experimental design': 17, 'MOLECULAR AND CELLULAR BIOLOGY, Apr. 2002, p. 2375–2387 Vol. 22, No. 7': 2, '5.2. Implications for Formation of Crustal Plateau Structures': 4, 'Materials and methods': 35, 'Flavones inhibit angiogenesis': 1, '1.1. Contribution': 1, '4.2. Induction of A. fumigatus GST expression with CDNB and H2O2': 1, '3.3 Dynamic weaving in workflow reference model': 3, '7 Numerical experiments': 4, '2. Method': 13, '2. METHODS': 7, '3.4. Higher phosphocreatine levels were accompanied by higher amounts of glycolytic enzyme intermediates and oxidative stress in tender meat samples': 1, '3. Proposed self-tuning iterated greedy algorithm': 2, '1. Introduction & Background': 2, 'Identification of non-conserved va-miRNAs': 1, 'Personality as a Risk Factor for Alcohol-Related Behavior': 3, '5.6 Limitations': 1, 'SMT3': 1, 'In vertebrates, the taste system provides information used in the regulation of food ingestion. In mammals, each cell groupwithin the taste buds expresses either the': 3, 'Necdin interacts with Msx': 1, 'Changes in CO2 and O3 Effects Through Time': 4, '1.1 Overview': 1, 'Enumeration of mycobacteria': 1, 'Detection of SPARC and albumin': 1, '2.5. Analytical methods': 2, '2. Formulation of time-varying discrete-time wavelet transforms': 2, '3. Results and Discussion': 2, '3. A REAL OPTION TO INVEST UNDER CHOQUET-BROWNIAN AMBIGUITY': 4, 'nan': 19, '6.3.6. Discussion': 1, '3.2. Simultaneous protein extraction and enzymatic saccharification': 2, '8 RELATEDWORK': 1, 'Methodology': 37, '3. SUPPORT VECTOR MACHINES': 2, '6.2 Experiments': 1, '2.1 Endothelial cell studies': 3, '1. Background': 7, 'A. Progressive Scanning of the Region of Interest': 1, '4 Implementation': 6, '7. Application 2: symbolic summation and the transcendence of sequences': 4, '7 Implementation': 1, '3. RESULTS': 2, 'Materials and procedure': 1, "4. E'ect of FOD on fatigue crack ...

# %%
short_sectionName_dict = {}
for key in sectionName_dict.keys():
    if sectionName_dict[key] >= 10:
        short_sectionName_dict[key] = sectionName_dict[key]
short_sectionName_dict
# Out:
# {'Introduction': 834,
#  'Discussion': 1240,
#  '3. Discussion': 31,
#  '1. Introduction': 349,
#  'RESULTS': 162,
#  '': 587,
#  'DISCUSSION': 483,
#  'Results': 359,
#  'INTRODUCTION': 263,
#  'MATERIALS AND METHODS': 16,
#  'Materials and Methods': 30,
#  'Background': 101,
#  '1. INTRODUCTION': 54,
#  'Methods': 800,
#  '1 Introduction': 160,
#  '2. Methods': 60,
#  'Method': 87,
#  'Results and discussion': 74,
#  'METHODS': 296,
#  'Implementation': 15,
#  '3. Results': 17,
#  'Present Address:': 13,
#  '4. Discussion': 172,
#  'RESULTS AND DISCUSSION': 33,
#  'Experiments': 10,
#  '4. DISCUSSION': 16,
#  'Results and Discussion': 41,
#  'Experimental design': 17,
#  'Materials and methods': 35,
#  '2. Method': 13,
#  'nan': 19,
#  'Methodology': 37,
#  'METHOD': 11,
#  '4 Experiments': 19,
#  '3 Experiments': 12,
#  '5. Discussion': 16,
#  '4 Discussion': 16,
#  '6 Experiments': 11,
#  '3. Methods': 11,
#  '2 Methods': 25,
#  '5 Experiments': 16,
#  '4. Experiments': 10,
#  '2 Related Work': 11,
#  '1 INTRODUCTION': 10}

# %%
# Barplot for all sectionNames that have more than 10 occurrences in the training dataset
plt.figure(figsize=(10, 8))
plt.title("Training dataset sectionNames >= 10 occurrences")
plt.xlabel("sectionName"); plt.ylabel("Count")
plt.xticks(rotation=90)
plt.bar(short_sectionName_dict.keys(), short_sectionName_dict.values(), color='g')
# Out:
# <BarContainer object of 44 artists>

# %%
train_jsonl['label_confidence']
# Out:
# 0       1.0000
# 1       1.0000
# 2       1.0000
# 3       1.0000
# 4       1.0000
#          ...
# 8238    0.7350
# 8239    0.7508
# 8240    1.0000
# 8241       NaN
# 8242    1.0000
# Name: label_confidence, Length: 8243, dtype: float64
